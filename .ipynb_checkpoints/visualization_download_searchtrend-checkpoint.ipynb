# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import requests
from bs4 import BeautifulSoup
import os
import seaborn as sns
import datetime
from dateutil.relativedelta import relativedelta

# %%
options = webdriver.ChromeOptions()
#options.add_argument('headless')
options.add_argument('disable-gpu')
options.add_argument('lang=ko_KR')
prefs = {"profile.default_content_setting_values.notifications": 2} 
options.add_experimental_option("prefs", prefs)
driver = webdriver.Chrome('./chromedriver', options=options)

# %%
k='치즈볼'
now = datetime.datetime.now() - datetime.timedelta(days = 1)
Gdate = now.strftime('%Y-%m-%d')
Kdate = now.strftime('%Y%m%d')
oneyear = now + relativedelta(years=-1)
Goneyear = oneyear.strftime('%Y-%m-%d')
Koneyear = oneyear.strftime('%Y%m%d')
print(Gdate, '\n', Kdate)
print(Goneyear, '\n', Koneyear)
# Out:
# 2020-10-18
#  20201018
# 2019-10-18
#  20191018

# %%
#Kakaodatatrend 파일 다운로드
url = 'https://datatrend.kakao.com/result?q={0}&from={1}&to={2}&interval=w'.format(k,Koneyear,Kdate)
driver.get(url)
time.sleep(0.5)

# %%
driver.find_element_by_xpath('//*[@id="root"]/div/header/div/div/a[2]').click()

# %%
df_daum=pd.read_excel('C:/Users/02/Downloads/datatrend.xls')
df_daum.head(20)
# Out:
#                      기간 2019-10-18 ~ 2020-10-18
# 0                    기기                      전체
# 1                    성별                      전체
# 2                    연령                      전체
# 3                    지역                      전체
# 4                   NaN                     NaN
# 5                    주제        통합검색, 검색어 변화량 추이
# 6                     일                     치즈볼
# 7   2019-10-14 00:00:00                      86
# 8   2019-10-21 00:00:00                      78
# 9   2019-10-28 00:00:00                      75
# 10  2019-11-04 00:00:00                      63
# 11  2019-11-11 00:00:00                      69
# 12  2019-11-18 00:00:00                      59
# 13  2019-11-25 00:00:00                      61
# 14  2019-12-02 00:00:00                      63
# 15  2019-12-09 00:00:00                      84
# 16  2019-12-16 00:00:00                      69
# 17  2019-12-23 00:00:00                      54
# 18  2019-12-30 00:00:00                      63
# 19  2020-01-06 00:00:00                      55

# %%
clean_daum = df_daum.loc[7:58] 
clean_daum.columns =["date","kakao"]
clean_daum.reset_index(drop=True, inplace=True)
print(clean_daum.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    52 non-null     object
#  1   kakao   52 non-null     object
# dtypes: object(2)
# memory usage: 960.0+ bytes
# None

# %%
os.remove('C:/Users/02/Downloads/datatrend.xls')

# %%
#googletrend 파일 다운로드
url = 'https://trends.google.co.kr/trends/explore?date={0}%20{1}&geo=KR&q={2}'.format(Goneyear,Gdate,k)
driver.get(url)
time.sleep(2.0)
driver.get(url)
time.sleep(2.0)

# %%
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/md-content/div/div/div[1]/trends-widget/ng-include/widget/div/div/div/widget-actions/div/button[1]/i').click()

# %%
df_google=pd.read_csv('C:/Users/02/Downloads/multiTimeline.csv')

# %%
df_google = df_google.reset_index()
clean_google = df_google.loc[1:53] 
clean_google.columns = ["date","google"]
clean_google.reset_index(drop=True,inplace=True)
print(clean_google)
# Out:
#           date google
# 0   2019-10-20     73
# 1   2019-10-27     31
# 2   2019-11-03     31
# 3   2019-11-10     34
# 4   2019-11-17     23
# 5   2019-11-24     45
# 6   2019-12-01     34
# 7   2019-12-08     36
# 8   2019-12-15     42
# 9   2019-12-22     34
# 10  2019-12-29     15
# 11  2020-01-05     37
# 12  2020-01-12     55
# 13  2020-01-19     15
# 14  2020-01-26     21
# 15  2020-02-02     41
# 16  2020-02-09     33
# 17  2020-02-16     35
# 18  2020-02-23     39
# 19  2020-03-01     51
# 20  2020-03-08     51
# 21  2020-03-15     32
# 22  2020-03-22     41
# 23  2020-03-29     55
# 24  2020-04-05     48
# 25  2020-04-12     57
# 26  2020-04-19     32
# 27  2020-04-26     32
# 28  2020-05-03     40
# 29  2020-05-10     49
# 30  2020-05-17     42
# 31  2020-05-24     45
# 32  2020-05-31     39
# 33  2020-06-07     46
# 34  2020-06-14     42
# 35  2020-06-21     39
# 36  2020-06-28     37
# 37  2020-07-05     31
# 38  2020-07-12     29
# 39  2020-07-19     46
# 40  2020-07-26     26
# 41  2020-08-02     40
# 42  2020-08-09     57
# 43  2020-08-16     29
# 44  2020-08-23     54
# 45  2020-08-30     48
# 46  2020-09-06     82
# 47  2020-09-13    100
# 48  2020-09-20     93
# 49  2020-09-27     52
# 50  2020-10-04     64
# 51  2020-10-11     73

# %%
os.remove('C:/Users/02/Downloads/multiTimeline.csv')

# %%
#naver
url = 'https://datalab.naver.com/keyword/trendSearch.naver'
driver.get(url)
time.sleep(0.5)

# %%
driver.find_element_by_id('item_keyword1').send_keys(k)
driver.find_element_by_id('timeDimensionTitle').send_keys(Keys.ENTER)
driver.find_element_by_xpath('//*[@id="timeDimensionDiv"]/ul/li[2]/a').click()
driver.find_element_by_xpath('//*[@id="content"]/div/div[2]/div[1]/div/form/fieldset/a/span').click()

# %%
driver.find_element_by_xpath('//*[@id="content"]/div/div[1]/div[1]/div/div/div/div/div/div[1]/div[4]/a').click()

# %%
df_naver=pd.read_excel('C:/Users/02/Downloads/datalab.xlsx')

# %%
clean_naver = df_naver.loc[7:59] 
clean_naver.columns = ["date","naver"]
clean_naver.reset_index(drop=True,inplace=True)
print(clean_naver)
# Out:
#           date     naver
# 0   2019-10-14  64.70618
# 1   2019-10-21  72.08369
# 2   2019-10-28  62.38753
# 3   2019-11-04  57.51889
# 4   2019-11-11  56.96879
# 5   2019-11-18  54.92776
# 6   2019-11-25  54.49591
# 7   2019-12-02  56.40326
# 8   2019-12-09   58.9584
# 9   2019-12-16  56.84026
# 10  2019-12-23  54.62958
# 11  2019-12-30  55.55498
# 12  2020-01-06  56.99449
# 13  2020-01-13  59.70387
# 14  2020-01-20  48.38825
# 15  2020-01-27  62.29499
# 16  2020-02-03  76.73641
# 17  2020-02-10  84.14991
# 18  2020-02-17   92.9618
# 39  2020-07-13  48.72243    53     46
# 40  2020-07-20  44.10056    40     26
# 41  2020-07-27  41.77163    42     40
# 42  2020-08-03  46.81507    42     57
# 43  2020-08-10   57.6577    46     29
# 44  2020-08-17  59.73471    51     54
# 45  2020-08-24  66.68037    59     48
# 46  2020-08-31  64.42856    60     82
# 47  2020-09-07  87.42481    81    100
# 48  2020-09-14  81.15778    80     93
# 49  2020-09-21  55.80689    46     52
# 50  2020-09-28  48.73785    40     64
# 51  2020-10-05  47.92041    46     73

# %%
total_df['date'] = pd.to_datetime(total_df['date'])
total_df.set_index('date', inplace=True)
print(total_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52 entries, 2019-10-14 to 2020-10-05
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   naver   52 non-null     int32
#  1   kakao   52 non-null     int32
#  2   google  52 non-null     object
# dtypes: int32(2), object(1)
# memory usage: 1.2+ KB
# None

# %%
total_df=total_df.astype(int)
print(total_df.info())
total_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52 entries, 2019-10-14 to 2020-10-05
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   naver   52 non-null     int32
#  1   kakao   52 non-null     int32
#  2   google  52 non-null     int32
# dtypes: int32(3)
# memory usage: 1.0 KB
# None
#             naver  kakao  google
# date
# 2019-10-14     64     86      73
# 2019-10-21     72     78      31
# 2019-10-28     62     75      31
# 2019-11-04     57     63      34
# 2019-11-11     56     69      23
# 2019-11-18     54     59      45
# 2019-11-25     54     61      34
# 2019-12-02     56     63      36
# 2019-12-09     58     84      42
# 2019-12-16     56     69      34
# 2019-12-23     54     54      15
# 2019-12-30     55     63      37
# 2020-01-06     56     55      55
# 2020-01-13     59     55      15
# 2020-01-20     48     49      21
# 2020-01-27     62     69      41
# 2020-02-03     76     87      33
# 2020-02-10     84     86      35
# 2020-02-17     92     74      39
# 2020-02-24     95     86      51
# 2020-03-02     88     91      51
# 2020-03-09     95    100      32
# 2020-03-16     90     96      41
# 2020-03-23     85     77      55
# 2020-03-30    100     88      48
# 2020-04-06     92     85      57
# 2020-04-13     74     74      32
# 2020-04-20     69     74      32
# 2020-04-27     62     60      40
# 2020-05-04     58     85      49
# 2020-05-11     66     87      42
# 2020-05-18     64     76      45
# 2020-05-25     54     71      39
# 2020-06-01     48     64      46
# 2020-06-08     50     52      42
# 2020-06-15     42     49      39
# 2020-06-22     43     45      37
# 2020-06-29     44     47      31
# 2020-07-06     46     48      29
# 2020-07-13     48     53      46
# 2020-07-20     44     40      26
# 2020-07-27     41     42      40
# 2020-08-03     46     42      57
# 2020-08-10     57     46      29
# 2020-08-17     59     51      54
# 2020-08-24     66     59      48
# 2020-08-31     64     60      82
# 2020-09-07     87     81     100
# 2020-09-14     81     80      93
# 2020-09-21     55     46      52
# 2020-09-28     48     40      64
# 2020-10-05     47     46      73

# %%
plt.style.use('ggplot')
total_df.plot(linewidth=3, figsize=(20, 10))
plt.title('Search Trend', size=30)
plt.ylabel('Frequency', size=20)
plt.xlabel('Date', size=20)
plt.show()

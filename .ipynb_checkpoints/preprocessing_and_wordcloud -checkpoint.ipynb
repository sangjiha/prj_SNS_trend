# %%
# !pip install customized_konlpy
# Out:
# Collecting customized_konlpy
#   Downloading customized_konlpy-0.0.64-py3-none-any.whl (881 kB)
# Requirement already satisfied: konlpy>=0.4.4 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from customized_konlpy) (0.5.2)
# Requirement already satisfied: Jpype1>=0.6.1 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from customized_konlpy) (1.0.2)
# Collecting beautifulsoup4==4.6.0
#   Using cached beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
# Requirement already satisfied: tweepy>=3.7.0 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from konlpy>=0.4.4->customized_konlpy) (3.9.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from konlpy>=0.4.4->customized_konlpy) (4.5.2)
# Requirement already satisfied: numpy>=1.6 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from konlpy>=0.4.4->customized_konlpy) (1.19.1)
# Requirement already satisfied: colorama in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from konlpy>=0.4.4->customized_konlpy) (0.4.3)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from Jpype1>=0.6.1->customized_konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (2.24.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (3.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\07\anaconda3\envs\machinelearning\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy>=0.4.4->customized_konlpy) (1.7.1)
# Installing collected packages: customized-konlpy, beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.9.1
#     Uninstalling beautifulsoup4-4.9.1:
#       Successfully uninstalled beautifulsoup4-4.9.1
# Successfully installed beautifulsoup4-4.6.0 customized-konlpy-0.0.64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt 
from ckonlpy.tag import Twitter #prompt에서 pip Customized Konlpy 로 패키지 설치

# %%
#크롤링한 데이터 파일 불러오기
#중복제거 및 널값제거 
df = pd.read_csv('../prj_sns_trend_private/crawling_치즈볼_from20200101_to20201015.csv', index_col=0)
df.drop_duplicates(inplace=True)
df.dropna(subset=['title'],how='any',inplace=True)
df.reset_index(drop=True, inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18779 entries, 0 to 18778
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   18779 non-null  object
#  1   date    18779 non-null  object
# dtypes: object(2)
# memory usage: 293.5+ KB
# None

# %%
#한국어에 사용할 토크나이저
twitter = Twitter()
# Out:
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#토큰화에 제외할 단어 토크나이저 딕셔너리에 추가 
twitter.add_dictionary(['뿌링클','맛스타그램', '맛스타', '푸라닭', '스타그램', '인스타', '또래오래', '배달의민족','배민', 'instagram', '뿌링클', '고추바사삭', '뿌링뿌링','뿌링뿌링소스' ,'뿌링소스', '또래오래', '인스타 그램','인스타그램', '황금올리브','네고왕','맘스터치','에어프라이어','블랙치즈볼','블랙알리오','청년치킨','청년피자'], 'Noun',force=True)

#for word in imp_wrd['important_words']:
#    twitter.add_dictionary('{}', 'Noun').format(word)

# %%
#딕셔너리 추가된 것 테스트 
twitter.morphs('일주일만에 다시 찾은 뿌링클 맛스타그램 네고왕')
# Out:
# ['일주일', '만에', '다시', '찾은', '뿌링클', '맛스타그램', '네고왕']

# %%
#stopwords 현 디렉토리에 추가 해야함 
stopwords = pd.read_csv('./stopwords.csv',  encoding='CP949' ,index_col = 0) 
print(stopwords.head())
print(stopwords.tail())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-b5595aca6e09> in <module>
#       1 #stopwords 현 디렉토리에 추가 해야함
# ----> 2 stopwords = pd.read_csv('./stopwords.csv',  encoding='CP949' ,index_col = 0)
#       3 print(stopwords.head())
#       4 print(stopwords.tail())
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1979         if kwds.get("compression") is None and encoding:
#    1980             if isinstance(src, str):
# -> 1981                 src = open(src, "rb")
#    1982                 self.handles.append(src)
#    1983
#
# FileNotFoundError: [Errno 2] No such file or directory: './stopwords.csv'

# %%
#프랜차이즈 리스트 
stores = pd.read_excel('./프렌차이즈.xlsx')
stores
stores.reset_index(drop=True, inplace=True)
print(stores.info()) 
stores.columns
#stores = pd.read_csv('./stores.csv', 
#                    encoding='euc-kr', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-5691c9673c9a> in <module>
#       1 #프랜차이즈 리스트
# ----> 2 stores = pd.read_excel('./프렌차이즈.xlsx')
#       3 stores
#       4 stores.reset_index(drop=True, inplace=True)
#       5 print(stores.info())
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: './프렌차이즈.xlsx'

# %%
#토큰화 및 텍스트 데이터 전처리 
cleaned_sentences = []

for sentence in df['title']:
    E_sentence = re.sub('[^a-zA-Z]',' ', sentence)  #영어텍스트만 뽑아오기 
    E_token = E_sentence.split(' ')   #영어텍스트를 띄어쓰기 기준으로 토큰화 
    K_sentence = re.sub('[^가-힣]',' ', sentence)  #한글텍스트만 뽑아오기
    K_token = twitter.nouns(K_sentence) #한글텍스트를 토큰화 및 명사만 남기기 
    K_token = pd.DataFrame(K_token, columns=['word'])   #토큰화된 한글텍스트를 다시 데이터프레임으로 만들기
    token = E_token + list(K_token['word'])    #토큰화된 한글, 영어텍스트를 합치기 
    cleaned_token = pd.DataFrame(token, columns=['word'])   #합친 것을 다시 데이터프레임으로 만들기 
    words = []
    for word in cleaned_token['word']:  #불용어 제거 
       if len(word)>1: 
          if word not in (list(stopwords['stopword'])): 
              words.append(word)
          else: print(word) 
       else: print(word)    
    cleaned_sentence = ' '.join(words)
    cleaned_sentences.append(cleaned_sentence)

df['cleaned_content'] = cleaned_sentences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-530eadce3d00> in <module>
#      13     for word in cleaned_token['word']:  #불용어 제거
#      14        if len(word)>1:
# ---> 15           if word not in (list(stopwords['stopword'])):
#      16               words.append(word)
#      17           else: print(word)
#
# NameError: name 'stopwords' is not defined

# %%
"""
#형용사와 명사만 남길경우 사용 
cleaned_sentences = []

for sentence in df['title']:
    E_sentence = re.sub('[^a-zA-Z]',' ', sentence)  #영어텍스트를 띄어쓰기 기준으로 토큰화 
    E_token = E_sentence.split(' ')
    K_sentence = re.sub('[^가-힣]',' ', sentence)  #한글텍스트를 토큰화 
    K_token = twitter.pos(K_sentence)
    K_token = pd.DataFrame(K_token, columns=['word','class'])   #토큰화된 한글텍스트를 다시 데이터프레임으로 만들기
    K_token = K_token[(K_token['class']=='Noun')|(K_token['class']=='Adjective')] 
    token = E_token + list(K_token['word'])    #토큰화된 한글, 영어텍스트를 합치기 
    cleaned_token = pd.DataFrame(token, columns=['word'])   #합친 것을 다시 데이터프레임으로 만들기 
    words = []
    for word in cleaned_token['word']:  #불용어 제거 
       if len(word)>1: 
          if word not in (list(stopwords['stopword'])): 
              words.append(word)
          else: print(word) 
       else: print(word)    
    cleaned_sentence = ' '.join(words)
    cleaned_sentences.append(cleaned_sentence)

df['cleaned_content'] = cleaned_sentences
"""

# %%
print(df.info())
print(df.head(30))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18783 entries, 0 to 18782
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             18783 non-null  object
#  1   title            18783 non-null  object
#  2   youtuber         2717 non-null   object
#  3   comment          2717 non-null   object
#  4   cleaned_content  18783 non-null  object
# dtypes: object(5)
# memory usage: 733.8+ KB
# None
#           date                                              title youtuber  \
# 0   2020-09-26  60계치킨 메뉴 짜파치킨치즈볼 처음이자 마지막 쫀득 치즈볼 5개 5000원 배달팁 ...      NaN
# 1   2020-10-13  에어프라이어 냉동치킨 애슐리 치킨 스윗 콤보치즈볼 후기 모짜렐라치즈볼도 금방 만들어...      NaN
# 2   2020-10-15  후기 밥솥  시금치적채애호박 소고기 이유식 아기치즈 치즈볼 흑 아기간식치즈볼 렌자렌...      NaN
# 3   2020-09-15  bhc치킨 메뉴 뿌링클 치즈볼 다 조앙 늘어나는건 볼 수 없었지만 그래도 마시써요 ...      NaN
# 4   2020-10-09  비비큐 네고왕 광희나는 메이플버터갈릭치킨 황금올리브 치즈볼 닭껍질튀김 JMT 솔직후...      NaN
# 5   2020-10-02  이마트 트레이더스 순살치킨  크림 치즈볼 구입 솔직후기 크림치즈볼입니다 겉면은 바삭...      NaN
# 6   2020-09-21  마켓컬리 내돈내산 추천템 다이어트 식단요리 기록 치즈볼 콩국수 유튜브에서 핏블리 치...      NaN
# 7   2020-09-27  네네치킨 메뉴 추천 파닭 맛있지 사이드메뉴는 치즈볼  단짠의 조화가 있는 치즈볼이라...      NaN
# 8   2020-10-09  치킨콤보 애슐리 치즈볼과 간장치킨 강추 홈스토랑 오픈함 치즈가 장난아니죠  깜놀함 ...      NaN
# 9   2020-10-04  안성 푸라닭 블랙알리오와 고추마요 보틀 치즈볼 후기  포장주문해오고 치킨먹는동안 굳...      NaN
# 10  2020-09-18  쿠캣 인기 메뉴 다 먹어봄 치즈볼순살 찜닭감자탕 볶음밥오징어 젓갈띵커바디 도시락 있...      NaN
# 11  2020-09-16  남산타워에서 놀아보자 라이언 치즈볼 어드벤처 방문 남산타워 안에 라이언 치즈볼 어드...      NaN
# 12  2020-09-16  아이 간식 하기 좋은 핫도그 치즈볼 츄러스까지 안에 치즈가 쏙쏙 두 가지 맛을 맛볼...      NaN
# 13  2020-09-15  던킨 해피오더캡슐커피프레즐치즈볼핫도그 이번엔 캡슐 1줄과 핫도그치즈볼 치즈핫도그15...      NaN
# 14  2020-10-10  냉동치킨 추천 에어프라이어 조리 애슐리 치킨 스윗 콤보  치즈볼 그리고 치즈볼도 에...      NaN
# 15  2020-10-12  에어프라이어 냉동치킨  애슐리치킨 스윗콤보  치즈볼 먹는동안에 치즈볼을 후다닥 돌려...      NaN
# 16  2020-10-06  노브랜드버거메뉴 종류와 인절미 치즈볼 사이드메뉴 중에서도 인절미 치즈볼이 많은 분이...      NaN
# 17  2020-09-20  리뷰 BHC 뿌링클 치즈볼 세트 뿌링가루가 뿌려진 메뉴들이 점점 늘고 있는데 그 중...      NaN
# 18  2020-10-05  일산경기도살 찌는 소리 여기까지 들리네여T_T20201004BBQ 네고왕 메이플버터...      NaN
# 19  2020-10-08  간편식간식파리바게트 바삭 치즈볼 뭔가 치즈가 덜 녹은채로 조리되는 경우가 많아서 불...      NaN
# 20  2020-09-24  핫도그와 츄러스 치즈볼 아이간식으로 핫츄 식감의 치즈볼을 만날 수 있답니다 달콤하면...      NaN
# 21  2020-09-26  카카오톡 선물하기  BHC 뿌링클치킨뿌링소떡치즈볼모바일쿠폰 사용하기 아니 소떡소떡 ...      NaN
# 22  2020-10-05  BBQ치킨  메이플버터갈릭 치킨 황금올리브 치킨 치즈볼  네고왕 할인 10월 8일까...      NaN
# 23  2020-10-09  내돈내산 BBQ 광희나는 갈릭치킨메이플버터갈릭치킨  BBQ 모듬볼치즈볼 리뷰 더블치...      NaN
# 24  2020-09-26  맘스터치 메뉴커플강정콤보에  내슈빌 핫치킨버거치즈볼 존맛탱 콤보는 싸이버거 2 버거...      NaN
# 25  2020-10-15  애슐리 냉동치킨 스윗콤보 모짜렐라 치즈볼 치킨콤보 치킨추천  애슐리치즈볼 안에 이렇...      NaN
# 26  2020-09-17  애슐리 오리지널 통살 치킨  모짜렐라 치즈볼 후기 모짜렐라 치즈볼을 산 가장 큰 이...      NaN
# 27  2020-09-27  60계 치킨 먹고오다 고추치킨  간지치킨  치즈볼 뇸뇸 60계 치킨 당진 기지시점 ...      NaN
# 28  2020-09-30  BBQ 치킨은 비비큐 황금올리브랑 치즈볼이 짱인듯 네고왕 이벤트를 볼 때만 해도 심...      NaN
# 29  2020-10-08  기프티콘으로 받은 bhc치킨 뿌링클치즈볼 치즈가 식기 전에 치즈볼부터 념념 뿌링클 ...      NaN
#
#    comment                                    cleaned_content
# 0      NaN       치킨 치킨 치즈볼 처음 이자 마지막 쫀득 치즈볼 배달 결제 별내 후기 치킨 치킨
# 1      NaN  에어프라이어 냉동 치킨 애슐리 치킨 스윗 콤보 치즈볼 후기 모짜렐라 치즈볼 금방 따...
# 2      NaN  후기 밥솥 시금치 적채 애호박 소고기 이유식 아기치 치즈볼 아기 간식 치즈볼 렌자렌...
# 3      NaN           bhc 치킨 뿌링클 치즈볼 조앙 메이플시럽 어가 고요 바삭 치즈스틱 이건
# 4      NaN  JMT 비비큐 네고왕 광희 메이플 버터 갈릭 치킨 황금올리브 치즈볼 껍질 튀김 솔직...
# 5      NaN  이마트 레이더스 치킨 크림 치즈볼 구입 솔직 후기 크림 치즈볼 바삭 안쪽 쫄깃 찹쌀...
# 6      NaN  마켓 컬리 다이어트 식단 요리 기록 치즈볼 콩국수 유튜브 핏블리 치즈볼 먹방 다가 ...
# 7      NaN          네네 치킨 파닭 사이드 치즈볼 조화 치즈볼 이건 는걸 치즈 어보 고소 치즈
# 8      NaN  치킨 콤보 애슐리 치즈볼 간장 치킨 강추 스토 오픈 치즈 장난 깜놀 치즈볼 쭈욱 대...
# 9      NaN  안성 푸라닭 블랙알리오 고추 보틀 치즈볼 후기 포장 치킨 어진 치즈볼 전자레인지 정...
# 10     NaN  쿠캣 인기 치즈볼 찜닭 감자탕 볶음밥 오징어 젓갈 띵커 바디 도시락 치즈볼 걱정 대...
# 11     NaN  VR 남산타워 아보 라이언 치즈볼 어드벤처 방문 남산타워 라이언 치즈볼 어드벤처 구...
# 12     NaN    간식 핫도그 치즈볼 츄러스 치즈 쏙쏙 가지 고소 특별 해지 츄러스 치즈볼 츄러스 원래
# 13     NaN  던킨 해피 캡슐 커피 프레즐 치즈볼 핫도그 캡슐 핫도그 치즈볼 치즈 핫도그 소시지 ...
# 14     NaN  냉동 치킨 에어프라이어 조리 애슐리 치킨 스윗 콤보 치즈볼 치즈볼 에어프라이어 봉지...
# 15     NaN  에어프라이어 냉동 치킨 애슐리 치킨 스윗 콤보 치즈볼 치즈볼 후다닥 치킨 마찬가지 ...
# 16     NaN  브랜드 버거 종류 인절미 치즈볼 사이드 서도 인절미 치즈볼 궁금 해하 서도 치즈볼 ...
# 17     NaN   BHC 뿌링클 치즈볼 세트 뿌링 가루 점점 서도 치즈볼 옛날 도넛 치즈 어간 단순 아주
# 18     NaN  BBQ IPA 일산 경기도 소리 네고왕 메이플 버터 갈릭 황금올리브 치즈볼 마트 닭...
# 19     NaN   간편식 간식 파리바게트 바삭 치즈볼 뭔가 치즈 조리 경우 불신 제일 안전 빠방하 치즈볼
# 20     NaN  핫도그 츄러스 치즈볼 간식 핫츄 식감 치즈볼 만날 쭉쭉 치즈 때문 재미나 간식 치즈 쭉쭉
# 21     NaN  BHC BHC 카카오 선물 뿌링클 치킨 뿌링소떡 치즈볼 모바일 쿠폰 사용 개발 신분...
# 22     NaN  BBQ BBQ 치킨 메이플 버터 갈릭 치킨 황금올리브 치킨 치즈볼 네고왕 할인 메이...
# 23     NaN  BBQ BBQ 광희 갈릭 치킨 메이플 버터 갈릭 치킨 모듬볼 치즈볼 더블 치즈볼 크...
# 24     NaN  맘스터치 커플 강정 콤보 내슈빌 치킨 버거 치즈볼 존맛 콤보 싸이버 버거 변경 닭강...
# 25     NaN  애슐리 냉동 치킨 스윗 콤보 모짜렐라 치즈볼 치킨 콤보 치킨 애슐리 치즈볼 뉴욕 치...
# 26     NaN  애슐리 오리 통살 치킨 모짜렐라 치즈볼 후기 모짜렐라 치즈볼 가장 이유 치즈 봉지 ...
# 27     NaN  BHC 치킨 고오 고추 치킨 간지 치킨 치즈볼 뇸뇸 치킨 당진 기지시 메이플 시럽 ...
# 28     NaN  BBQ 치킨 비비큐 황금올리브 치즈볼 네고왕 이벤트 심드렁 막상 그게 지극 주관 견...
# 29     NaN  bhc 기프티콘 치킨 뿌링클 치즈볼 치즈 식기 치즈볼 념념 뿌링클 두번째 어보 반적...

# %%
#프랜차이즈 리스트의 치킨 프랜차이즈들이 언급된 문장만 남기기 
store_cleaned_content = []
for sentence in df['cleaned_content']:
    token = sentence.split(' ')
    tokens = pd.DataFrame(token, columns=['token'])
    for word in (list(tokens['token'])):

            if word in (list(stores['치킨'])): 
                store_cleaned_content.append(sentence)
                break
            

    
new_df = pd.DataFrame({'store_cleaned_content': store_cleaned_content})

print(new_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   store_cleaned_content  9568 non-null   object
# dtypes: object(1)
# memory usage: 74.9+ KB
# None

# %%
print(new_df.head())
print(new_df.info())
# Out:
#                                store_cleaned_content
# 0       치킨 치킨 치즈볼 처음 이자 마지막 쫀득 치즈볼 배달 결제 별내 후기 치킨 치킨
# 1  에어프라이어 냉동 치킨 애슐리 치킨 스윗 콤보 치즈볼 후기 모짜렐라 치즈볼 금방 따...
# 2           bhc 치킨 뿌링클 치즈볼 조앙 메이플시럽 어가 고요 바삭 치즈스틱 이건
# 3  JMT 비비큐 네고왕 광희 메이플 버터 갈릭 치킨 황금올리브 치즈볼 껍질 튀김 솔직...
# 4  이마트 레이더스 치킨 크림 치즈볼 구입 솔직 후기 크림 치즈볼 바삭 안쪽 쫄깃 찹쌀...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   store_cleaned_content  9568 non-null   object
# dtypes: object(1)
# memory usage: 74.9+ KB
# None

# %%
#필요없는 title 컬럼의 데이터들을 '치즈볼'로 통일해서 채움 -> 동일한 컬럼을 기준으로 one sentence로 합치기 위함 

df['title']='치즈볼'

# %%
print(df.head())
# Out:
#          date title youtuber comment  \
# 0  2020-09-26   치즈볼      NaN     NaN
# 1  2020-10-13   치즈볼      NaN     NaN
# 2  2020-10-15   치즈볼      NaN     NaN
# 3  2020-09-15   치즈볼      NaN     NaN
# 4  2020-10-09   치즈볼      NaN     NaN
#
#                                      cleaned_content
# 0       치킨 치킨 치즈볼 처음 이자 마지막 쫀득 치즈볼 배달 결제 별내 후기 치킨 치킨
# 1  에어프라이어 냉동 치킨 애슐리 치킨 스윗 콤보 치즈볼 후기 모짜렐라 치즈볼 금방 따...
# 2  후기 밥솥 시금치 적채 애호박 소고기 이유식 아기치 치즈볼 아기 간식 치즈볼 렌자렌...
# 3           bhc 치킨 뿌링클 치즈볼 조앙 메이플시럽 어가 고요 바삭 치즈스틱 이건
# 4  JMT 비비큐 네고왕 광희 메이플 버터 갈릭 치킨 황금올리브 치즈볼 껍질 튀김 솔직...

# %%
#one sentence 만들기
review_one_sentences = []
titles = []

for title in df['title'].unique():
    temp = df[df['title']==title]['cleaned_content']
    review_one_sentence = ' '.join(list(temp)) 
    review_one_sentences.append(review_one_sentence)
    titles.append(title)
    
df_review_one_sentence = pd.DataFrame({'title':titles, 'review_one_sentence':review_one_sentences})
print(df_review_one_sentence.head())
print(df_review_one_sentence.info())
# Out:
#   title                                review_one_sentence
# 0   치즈볼  치킨 치킨 치즈볼 처음 이자 마지막 쫀득 치즈볼 배달 결제 별내 후기 치킨 치킨 에...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                1 non-null      object
#  1   review_one_sentence  1 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes
# None

# %%
#one sentence로 합쳐진 데이터를 X에 저장 
X=df_review_one_sentence
print(X.head())
# Out:
#   title                                review_one_sentence
# 0   치즈볼  치킨 치킨 치즈볼 처음 이자 마지막 쫀득 치즈볼 배달 결제 별내 후기 치킨 치킨 에...

# %%
#워드클라우드 합치기 
import pandas as pd
pd.set_option('display.max_row',500)
pd.set_option('display.max_columns',100)
pd.set_option('display.unicode.east_asian_width',True) 
import numpy as np
import matplotlib.pyplot as plt

from wordcloud import WordCloud,STOPWORDS
from PIL import Image 
import collections

# %%
fontpath = './malgun.ttf'

# %%
#바꾸지 X 
_title='치즈볼'

# %%
_idx = X[X['title']==_title].index[0]

# %%
tokened_content_words = X['review_one_sentence'][_idx].split(' ')

# %%
textdict = collections.Counter(tokened_content_words)

# %%
wordcloude_img = WordCloud(background_color = 'white', max_words=300, font_path=fontpath).generate_from_frequencies(textdict)
plt.figure(figsize=(16,16))
plt.imshow(wordcloude_img, interpolation='bilinear')
plt.axis('off')
plt.show()

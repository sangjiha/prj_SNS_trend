# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt 
from ckonlpy.tag import Twitter #prompt에서 pip install customized_konlpy 로 패키지 설치
from matplotlib import font_manager, rc
import seaborn as sns

pd.set_option('display.max_row',500)
pd.set_option('display.max_columns',100)
pd.set_option('display.unicode.east_asian_width',True) 

from wordcloud import WordCloud,STOPWORDS
from PIL import Image 
import collections

# %%
font_path = './malgun.ttf' #내가 쓰고 싶은 폰트 파일 경로로 쓰면 됨. 현재 같은 폴더 안에 있음.
font_name = font_manager.FontProperties(fname=font_path).get_name() #get_name:폰트의 이름을 알려줌.
rc('font', family=font_name)

# %%
#크롤링한 데이터 파일 불러오기
#중복제거 및 널값제거 
df = pd.read_csv('./crawling_data/crawling_치즈볼_from20200101_to20201015.csv', index_col=0)
df.drop_duplicates(inplace=True)
df.dropna(subset=['title'],how='any',inplace=True)
df.reset_index(drop=True, inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40644 entries, 0 to 40643
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    40644 non-null  object
#  1   title   40644 non-null  object
# dtypes: object(2)
# memory usage: 635.2+ KB
# None

# %%
df.tail(100)
# Out:
#              date  \
# 40544  2020-09-13
# 40545  2020-08-24
# 40546  2020-10-10
# 40547  2020-09-18
# 40548  2020-09-17
# 40549  2020-08-23
# 40550  2020-09-21
# 40551  2020-09-29
# 40552  2020-06-16
# 40553  2020-05-20
# 40554  2020-05-14
# 40555  2020-05-09
# 40556  2020-01-13
# 40557  2020-02-06
# 40558  2020-08-29
# 40559  2020-05-30
# 40560  2020-10-09
# 40561  2020-09-29
# 40562  2020-09-23
# 40563  2020-09-30
# 40564  2020-09-23
# 40565  2020-09-21
# 40566  2020-10-02
# 40567  2020-09-26
# 40568  2020-09-18
# 40569  2020-09-22
# 40570  2020-09-17
# 40571  2020-10-05
# 40572  2020-10-13
# 40573  2020-09-27
# 40574  2020-09-16
# 40575  2020-09-22
# 40576  2020-09-22
# 40577  2020-09-21
# 40578  2020-09-29
# 40579  2020-09-16
# 40580  2020-07-19
# 40581  2020-09-28
# 40582  2020-07-31
# 40583  2020-09-16
# 40584  2020-03-17
# 40585  2020-02-19
# 40586  2020-09-18
# 40587  2020-09-22
# 40588  2020-09-17
# 40589  2020-09-21
# 40590  2020-10-03
# 40591  2020-09-02
# 40592  2020-06-12
# 40593  2020-08-08
# 40594  2020-04-14
# 40595  2020-04-15
# 40596  2020-04-28
# 40597  2020-03-30
# 40598  2020-09-22
# 40599  2020-10-11
# 40600  2020-09-16
# 40601  2020-09-21
# 40602  2020-02-20
# 40603  2020-09-05
# 40604  2020-09-18
# 40605  2020-10-05
# 40606  2020-06-09
# 40607  2020-09-28
# 40608  2020-09-23
# 40609  2020-04-28
# 40610  2020-05-12
# 40611  2020-09-29
# 40612  2020-01-22
# 40613  2020-02-04
# 40614  2020-09-17
# 40615  2020-08-20
# 40616  2020-05-27
# 40617  2020-08-20
# 40618  2020-06-13
# 40619  2020-09-10
# 40620  2020-06-23
# 40621  2020-08-18
# 40622  2020-06-24
# 40623  2020-04-29
# 40624  2020-07-29
# 40625  2020-05-26
# 40626  2020-05-06
# 40627  2020-05-11
# 40610  좋아요댓글 애슐리W 식사권증정 521 추첨 5월13일 수요일 내일 애슐리 치즈축제가...
# 40611                         천연 1급수를 사용하여 만든
# 40612  교촌에 치즈볼 나온거 알고 있었음  정신줄 놓을 것 같아 쫀득쫀득 부드러운 치즈볼 ...
# 40613  봄을 알리는 입춘과 함께 찾아온 설레는 신상 사이드메뉴 출시 소식ᴗ 달콤함의 끝판왕...
# 40614  BHC러버에게는 너무 쉬운 문제 4가지의 BHC메뉴명을 순서대로 적어보세요  힌트 ...
# 40615  또래오래 치즈볼 리얼치즈볼 불닭볼 또래오래에서 대용량 제품이 출시된다면......
# 40616           집콕 간식 대결 브리또냐  VS   치즈볼이냐
# 40617  웅 마쟈요 저 품앗이사랑해요 그리고 안주도맛나고 가성비 좋아서 이용합니다 요긴 수송...
# 40618     사곡상모동 에도요즘 핫한 치킨집 을  칭구가 또이집 닭 겁나 맛 있는데......
# 40619  띵동 주문하신 두끼 치떡세트 배달왔습니다  치킨떡볶이  단돈 2만원 실화  매 더 ...
# 40620  고양시원흥동 호세권 호치킨_고양원흥역점 6월25일목 OPEN 오픈이벤트......
# 40621                               우디 뚱치 최애 슈붕
# 40622  서울시상봉동 호세권 호치킨_상봉역점 6월25일목 OPEN 오픈이벤트......
# 40623  내일은 학교 수업 없는 날 기념으로 온 가족 야식 치킨 먹어요 우리 동네는 치즈볼이...
# 40624   지금까지 이런맛은 없었다             이것이 요리인가 간식인가 완전 맛있...
# 40625  와 이 비주얼은 모다 치즈볼 신상 1BOONKAKAOCOM 뻔한 치즈볼은 취급 안한...
# 40626  대문패산악회1점벙 달봉이치킨관저점_김효진 조건없이먼저주고또주는술이없는모임 대문패가하...
# 40627                    치킨하면 어디 문화동 달봉이치킨
# 40628  지금 완전 먹고싶은 뿌링클 치즈볼 감튀 조합  태그 당한 사람이 뿌링클에 치즈볼까지...
# 40629                                         북삼맛집
# 40630  투존치킨 OPEN EVENT 0212 수  0216 일 콜라 사이즈 UP......
# 40631                    치킨 미쳤다 치즈볼 은 더 미쳤다
# 40632  두둥  선데이치즈볼 x 카스 에디션 3탄   다가오는 주말 ......
# 40633  네네치킨고강점님이 네네치킨고강점에 있습니다 10월 8일 오후 100......
# 40634  배달의민족 요기요 부평 칼포니 부평칼포니 배달주문 서비스팍팍 치킨 국물떡볶이 차돌떡...
# 40635  네네치킨고강점님이 네네치킨고강점에 있습니다 10월 9일 오전 1000......
# 40636  네네치킨고강점님이 네네치킨고강점에 있습니다 10월 7일 오후 330......
# 40637                        네네치킨 고강점  0326832511
# 40638                                           지브로와
# 40639  연휴가 끝나서 힘들고 지칠 때 멕시카나치킨 을 찾아주세요 매콤단짠  뿌리고치킨 에 ...
# 40640                    배달의민족 순수치킨 3000원 할인
# 40641          금요일은 배달의민족 순수치킨  3000원 할인
# 40642  또래오래 목우촌 배달의민족 쿠폰 프로모션 치킨 이번 주 금토일 치킨파티 각 쉿 6월...
# 40643  순수치킨이 새로 쓰는 치킨의정석  가성비가성비갓성비순수치킨......

# %%
#한국어에 사용할 토크나이저
twitter = Twitter()
# Out:
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#토큰화에 제외할 단어 토크나이저 딕셔너리에 추가 
twitter.add_dictionary(['뿌링클','맛스타그램', '맛스타', '푸라닭', '인스타그램', '인스타', '또래오래', '배달의민족','배민', 'instagram', '뿌링클', '고추바사삭', '뿌링뿌링','뿌링뿌링소스' ,'뿌링소스', '또래오래', '인스타 그램','먹스타그램', '황금올리브','네고왕','맘스터치','에어프라이어','블랙치즈볼','블랙알리오','청년치킨','청년피자', '레시피', '프레시웨이', 'cj프레시웨이', '장보기', '가까운', '로켓프레시', '쿠팡', '이케아', '치킨스타그램', '트레이더스', '노브랜드', '노브랜드버거', '겉바속쫀', '겉바', '겉바속촉',
                        '달콤바삭치즈볼', '달콤바삭 치즈볼','뿌링치즈볼','뿌링 치즈볼', '바삭크림치즈볼','바삭크림 치즈볼'], 'Noun',force=True)

#for word in imp_wrd['important_words']:
#    twitter.add_dictionary('{}', 'Noun').format(word)

# %%
#딕셔너리 추가된 것 테스트 
twitter.morphs('일주일만에 다시 찾은 뿌링클 맛스타그램 네고왕 프레시웨이 인스타그램')
# Out:
# ['일주일', '만에', '다시', '찾은', '뿌링클', '맛스타그램', '네고왕', '프레시웨이', '인스타그램']

# %%
#stopwords 현 디렉토리에 추가 해야함 
stopwords = pd.read_csv('./stopwords_trend.csv',  encoding='CP949' ,index_col = 0) 
print(stopwords.head())
print(stopwords.tail())
# Out:
#   stopword
# 0       아
# 1       휴
# 2   아이구
# 3   아이쿠
# 4   아이고
#      stopword
# 661      추천
# 662      일상
# 663  있습니다
# 664      이라
# 665      많이

# %%
#프랜차이즈 리스트 
stores = pd.read_excel('./프렌차이즈.xlsx')
stores
stores.reset_index(drop=True, inplace=True)
print(stores.info()) 
stores.columns
#stores = pd.read_csv('./stores.csv', 
#                    encoding='euc-kr', index_col=0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835 entries, 0 to 1834
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   한식      1835 non-null   object
#  1   분식      455 non-null    object
#  2   중식      111 non-null    object
#  3   일식      201 non-null    object
#  4   양식      181 non-null    object
#  5   양식(외)   109 non-null    object
#  6   패스트푸드   102 non-null    object
#  7   치킨      527 non-null    object
#  8   피자      186 non-null    object
#  9   제과제빵    172 non-null    object
#  10  아이스크림   40 non-null     object
#  11  카페      456 non-null    object
#  12  커피외음료   84 non-null     object
#  13  술집      315 non-null    object
#  14  기타외식    1001 non-null   object
#  15  냉동식품    27 non-null     object
# dtypes: object(16)
# memory usage: 229.5+ KB
# None
# Index(['한식', '분식', '중식', '일식', '양식', '양식(외)', '패스트푸드',
#        '치킨', '피자', '제과제빵', '아이스크림', '카페', '커피외음료', '술집',
#        '기타외식', '냉동식품'],
#       dtype='object')

# %%
print(df['title'][0])
# Out:
# 오백예순두 번째 호기심까까  노브랜드버거 인절미치즈볼3알2900원   리뷰요청지에서 눈길을 사로잡은 한 알바분의 열띤 영업   노브랜드버거 버거 맛없어서 평소에 잘 안가는데  사이드라서 방문해봤어요   인절미 치즈볼이라니 이름부터 걍 침 주루룩   딴딴하게 잘 튀겨진 치즈볼 한 입 베어물어보니 허우허   진짜미쳤구만 너무 맛있습니다 내취향이야   겉은 콩고물설탕  꼬소롬 달콤달콤 속은 모짜렐라치즈  짭쫍짭쫍 고소 약간 치즈볼 꼬북칩 인절미ver    추천해주신 알바분 진자내가 가만안둬   여태 먹어본 치즈볼중 최고였던 호까 취향 신상이었습니닷   노브랜드버거노브랜드신세계치즈볼인절미치즈볼인절미할미입맛할매입맛치즈스타그램신상리뷰호기심까까_별5점호기심까까_노브랜드버거맛스타그램먹스타그램호기심까까

# %%
#형태소 분류
E_token = []
#twitter는 영어를 다 없애므로 영어는 띄어쓰기 기준으로 따로 처리해놓을 것


for sentence in df['title']:
    E_sentence = re.sub('[^a-zA-Z]',' ', sentence).split()  #영어텍스트만 뽑아오기
    E_token.append(E_sentence)
    
print(E_token)
    
#E_sentence = E_sentence.lower()
    
    
#E_sentence = E_sentence.split(' ')
    
    


#         E_sentence = E_sentence.lower()
#         #E_sentence = E_sentence.split(' ')   #영어텍스트를 띄어쓰기 기준으로 나눔
#         for b in E_sentence:
#             E_token += b
# Out:
# [['ver'], [], ['st'], ['bbq', 'bbqchicken', 'BBQ'], ['food', 'foodstagram'], [], ['L', 'bhc'], ['Youtube', 'Chan', 'Sori', 'asmr', 'ASMR', 'MUKBANG', 'Bbq', 'CHEESEBALL', 'SPICY', 'CHESSEBALL', 'eating', 'sounds', 'Full', 'video', 'is', 'on', 'YouTube', 'now', 'mukbang', 'mukbangvideo', 'asmr', 'eatingshow', 'bhc', 'chicken', 'realsound', 'likeforlikes', 'koreanfood', 'food', 'foodie', 'foodstagram', 'instagram', 'daily', 'follow', 'foodies', 'jmt'], [], ['pulmuone'], [], [], [], ['pulmuone'], [], ['cc'], [], ['thankspizza'], [], [], ['BHC'], [], ['bigsmile', 'sha', 'ssam'], [], ['g', 'Tip', 'g'], ['pulmuone'], ['food', 'foodie', 'chicken'], ['ASMR', 'ASMR'], ['ASMR', 'ASMR'], [], ['repost', 'go', 'tness', 'mnkorea', 'mn', 'g'], ['ittarocafecoffee'], ['diet'], ['bhc'], ['bhc'], ['bhc', 'L'], [], [], ['Repost', 'bhc', 'chicken', 'official', 'L', 'bhc'], ['pulmuone'], [], ['pulmuone'], ['f', 'fl', 'lfollowmebackfollowforfollowbacklikeforlikesootd'], ['pulmuone'], [], ['food', 'foodstagram', 'instagood', 'instagram', 'instadaily', 'instafood', 'daily'], [], [], [], [], [], [], [], [], [], [], ['selfie', 'selca', 'insta'], ['bhc'], [], [], [], ['bhc', 'foodfoodporn', 'foodstagram', 'daily'], ['bigsmile', 'up', 'n', 'down'], [], ['bbq', 'bbq'], [], ['lotteria', 'cheeseball'], ['SET', 'L'], ['October'], ['BBQ'], ['feat'], ['bhc'], [], ['pulmuone', 'v', 'v', 'v', 'v', 'v', 'v'], [], [], ['nyongyi', 'jibbab'], [], ['i', 'JMT'], ['bhc'], [], ['kg', 'msmartstorenavercomimsilncheese', 'since', 'imsilcheesecafe', 'imsilcheese', 'yogurt'], ['kyochon'], ['I', 'love', 'BHC'], [], ['g', 'g', 'daily', 'diet', 'dietfood'], ['BHC', 'bhc'], ['pulmuone'], ['JMT'], ['L'], [], ['jmt'], ['likeforlikes', 'likeforfollow', 'following', 'follow', 'like', 'daily', 'foodie'], ['pulmuone'], ['bhc', 'bhc', 'food', 'foodstagram', 'mukbang'], [], ['with', 'bbq'], [], ['todays', 'menu', 'cheese', 'balls', 'mellawnie', 'asmr', 'food', 'mukbang', 'mukbangasmr', 'asmreating', 'cheeseballs', 'cheese'], ['dailyinstainstagood'], [], ['pulmuone'], ['bhc', 'JMT', 'bhc', 'bhc'], ['pulmuone'], ['kobe', 'koreanfood', 'chicken', 'foodstagram', 'instagood', 'instalike', 'like', 'likes'], ['mlb', 'guess', 'ootd', 'dailylook'], ['kindgirl'], [], [], [], ['bhc'], [], ['d', 'dessert'], ['chicken', 'delicious', 'yammy', 'foodporn', 'daily'], ['pulmuone'], [], ['pulmuone'], ['followforfollowback', 'following', 'foodstagram', 'yum', 'chicken', 'lfl', 'likesforlike', 'foodie', 'bbq', 'bbq'], ['pulmuone'], [], ['BHC', 'BHC'], [], [], [], ['asmr'], ['Asmr'], ['pulmuone'], ['X', 'Tel'], [], ['pulmuone'], ['bbq'], ['pulmuone'], [], ['pulmuone'], ['monsterbsports', 'naveryk'], ['pulmuone'], ['bbq'], ['pulmuone'], [], [], ['MODERN', 'VAPE', 'SHOP', 'modernvape', 'modern', 'vape', 'modern', 'vape', 'modernvape', 'gs', 'modern', 'sj', 'modern', 'bs', 'modern', 'geoje', 'modern', 'vape', 'modern', 'jj', 'suhan', 'ootd', 'cheesecake', 'vapeliquid', 'eliquid', 'vape', 'vapemod', 'podsystem', 'podmod', 'csv'], [], [], ['c', 'c'], ['pulmuone'], ['YouTube', 'asmr', 'cheeseballs', 'asmreating', 'asmrfood', 'asmrsounds', 'asmrvideo', 'eat', 'eating', 'eatingshow', 'eatingsounds', 'mukbang', 'mukbangasmr', 'mukbangshow', 'mukbangvideo', 'youtube', 'yummy', 'delicious', 'miyuasmr'], ['pulmuone'], [], ['JMT', 'foodie', 'instaeats', 'foodporn', 'foodfi'], [], ['pulmuone'], ['BBQ', 'bbq', 'bbq'], [], [], [], ['pc'], ['food', 'foodie', 'instafood', 'foodpic', 'foodpics', 'foodporn', 'foodstagram', 'foodlike', 'hotplace'], [], ['bhc'], ['bbq', 'bbq', 'bhc', 'bbq', 'food', 'foodstagram'], [], ['g', 'Tip', 'g'], ['pulmuone'], ['bhc'], [], [], ['pulmuone'], ['bhc'], ['bhc'], ['D', 'NSP', 'whokar'], [], ['pulmuone'], ['pulmuone'], ['pulmuone'], [], [], [], ['jmt', 'pizza', 'chicken'], [], [], ['queensball', 'cheeseball'], [], [], ['pulmuone'], ['g', 'S', 'A', 'L', 'E'], [], [], ['ea'], [], [], [], [], ['bhc', 'bhc'], ['pulmuone'], ['BHC'], [], ['cc'], ['bbq', 'bbqchicken'], ['BHC'], ['pulmuone'], [], [], ['p ...

# %%
print(len(df))
print(len(E_token))
# Out:
# 40644
# 40644

# %%
#이중 리스트를 일차원으로 펴주기. one_sentence만들거아니면 필요 x
#E_token = sum(E_token,[])
#print(E_token[:5])

# %%
#한글 분류 후 형태 부여
K_sentence = []
for sentence in df['title']:
    sentence = re.sub('[^가-힣]',' ', sentence)
    K_sentence.append(twitter.pos(sentence))

# %%
print(K_sentence[1])
# Out:
# [('광고', 'Noun'), ('공구', 'Noun'), ('예고', 'Noun'), ('안녕', 'Noun'), ('하세요', 'Verb'), ('뚜뚜', 'Noun'), ('네', 'Josa'), ('간식', 'Noun'), ('뚜맘', 'Noun'), ('입니다', 'Adjective'), ('오래', 'Noun'), ('기다려', 'Verb'), ('주신', 'Noun'), ('오', 'Noun'), ('크리스', 'Noun'), ('피', 'Noun'), ('최저', 'Noun'), ('가공', 'Noun'), ('구', 'Noun'), ('드뎌', 'Noun'), ('데려왔어', 'Verb'), ('욜', 'Noun'), ('꺄', 'Noun'), ('아아', 'Noun'), ('아', 'Josa'), ('이번', 'Noun'), ('에는', 'Josa'), ('신제품', 'Noun'), ('쫀쫀초', 'Noun'), ('코볼', 'Noun'), ('에', 'Josa'), ('선착순', 'Noun'), ('명', 'Noun'), ('오도', 'Noun'), ('닭', 'Noun'), ('증정', 'Noun'), ('이벤트', 'Noun'), ('까지', 'Noun'), ('취향', 'Noun'), ('껏', 'Noun'), ('고를수', 'Verb'), ('있는', 'Adjective'), ('알찬', 'Adjective'), ('구성', 'Noun'), ('뚜뚜', 'Noun'), ('네', 'Josa'), ('서만', 'Verb'), ('가능', 'Noun'), ('하다는', 'Verb'), ('거', 'Noun'), ('아시', 'Noun'), ('죠', 'Josa'), ('공구', 'Noun'), ('때', 'Noun'), ('마다', 'Noun'), ('넘치는', 'Adjective'), ('물량', 'Noun'), ('때문', 'Noun'), ('에', 'Josa'), ('공구', 'Noun'), ('기간', 'Noun'), ('을', 'Josa'), ('길게는', 'Verb'), ('못', 'Noun'), ('잡아요', 'Verb'), ('이번', 'Noun'), ('에는', 'Josa'), ('꼭', 'Noun'), ('놓치지', 'Verb'), ('마세요', 'Verb'), ('어린이', 'Noun'), ('어른', 'Noun'), ('이', 'Josa'), ('간식', 'Noun'), ('으로', 'Josa'), ('쵝', 'Noun'), ('오오오', 'Noun'), ('내일', 'Noun'), ('오후', 'Noun'), ('시', 'Noun'), ('알람', 'Noun'), ('설정', 'Noun'), ('필뚜', 'Noun'), ('뚜', 'Noun'), ('아', 'Josa'), ('뚜', 'Noun'), ('지', 'Josa'), ('오', 'Noun'), ('크리스', 'Noun'), ('피', 'Noun'), ('에어프라이어', 'Noun'), ('간식', 'Noun'), ('멘보샤', 'Noun'), ('코코넛', 'Noun'), ('쉬', 'Noun'), ('림프', 'Noun'), ('오도', 'Noun'), ('닭', 'Noun'), ('치즈볼', 'Noun'), ('초코', 'Noun'), ('볼', 'Noun'), ('쫀쫀', 'Noun'), ('치즈볼', 'Noun'), ('쫀쫀', 'Noun'), ('초코', 'Noun'), ('볼', 'Noun'), ('아이', 'Noun'), ('간식', 'Noun'), ('간식', 'Noun'), ('야', 'Josa'), ('식', 'Noun'), ('안주', 'Noun'), ('최저', 'Noun'), ('가공', 'Noun'), ('구', 'Noun')]

# %%
#필요한 형태소(ADJ,NOUN)만 골라서 리스트에 추가하기
noun_adj_list=[]

for a in range(len(K_sentence)):
    noun_adj_list.append([])
    for word, tag in K_sentence[a]:
        if tag in ['Adjective'] :
            noun_adj_list[a].append(word)
        elif tag in ['Noun']:
            noun_adj_list[a].append(word)

# %%
print(len(noun_adj_list))
# Out:
# 40644

# %%
test = noun_adj_list[0] + E_token[0]
test
# Out:
# ['오백',
#  '예순',
#  '호기심',
#  '노브랜드버거',
#  '인절미',
#  '치즈볼',
#  '알',
#  '원',
#  '리뷰',
#  '요청',
#  '눈길',
#  '알바',
#  '분',
#  '열띤',
#  '영업',
#  '노브랜드버거',
#  '버거',
#  '맛없',
#  '어서',
#  '평소',
#  '사이드',
#  '라서',
#  '방문',
#  '어요',
#  '인절미',
#  '치즈볼',
#  '이름',
#  '부터',
#  '침',
#  '주루',
#  '딴딴하게',
#  '치즈볼',
#  '입',
#  '베',
#  '어물',
#  '어보',
#  '진짜',
#  '미쳤구만',
#  '맛있습니다',
#  '내',
#  '취향',
#  '겉',
#  '콩',
#  '고물',
#  '설탕',
#  '꼬소롬',
#  '달콤달콤',
#  '속',
#  '모짜렐라',
#  '치즈',
#  '짭쫍짭쫍',
#  '고소',
#  '약간',
#  '치즈볼',
#  '꼬북칩',
#  '인절미',
#  '추천',
#  '해주',
#  '신',
#  '알바',
#  '분',
#  '진자',
#  '내',
#  '여태',
#  '치즈볼',
#  '중',
#  '최고',
#  '호',
#  '취향',
#  '신상',
#  '었습니닷',
#  '노브랜드버거',
#  '노브랜드',
#  '신세계',
#  '치즈볼',
#  '절미',
#  '치즈볼',
#  '절미',
#  '할미',
#  '입맛',
#  '입맛',
#  '치즈',
#  '스타',
#  '그램',
#  '신상',
#  '리뷰',
#  '호기심',
#  '별',
#  '점',
#  '호기심',
#  '노브랜드버거',
#  '맛스타그램',
#  '먹스타그램',
#  '호기심',
#  'ver']

# %%
#영어랑 한글 합치고 데이터 프레임. 일단 token에 빈리스트개수를 df개수만큼
token = []
for a in range(len(df)):
    token.append([])

# %%
print(len(token))
print(len(E_token))
print(len(noun_adj_list))
# Out:
# 40644
# 40644
# 40644

# %%
#token의 빈리스트ㅇㅔ 각각 구한 값 넣어주기
for a in range(len(df)):    
    token[a] = E_token[a] + noun_adj_list[a]

# %%
print(token[0])
# Out:
# ['ver', '오백', '예순', '호기심', '노브랜드버거', '인절미', '치즈볼', '알', '원', '리뷰', '요청', '눈길', '알바', '분', '열띤', '영업', '노브랜드버거', '버거', '맛없', '어서', '평소', '사이드', '라서', '방문', '어요', '인절미', '치즈볼', '이름', '부터', '침', '주루', '딴딴하게', '치즈볼', '입', '베', '어물', '어보', '진짜', '미쳤구만', '맛있습니다', '내', '취향', '겉', '콩', '고물', '설탕', '꼬소롬', '달콤달콤', '속', '모짜렐라', '치즈', '짭쫍짭쫍', '고소', '약간', '치즈볼', '꼬북칩', '인절미', '추천', '해주', '신', '알바', '분', '진자', '내', '여태', '치즈볼', '중', '최고', '호', '취향', '신상', '었습니닷', '노브랜드버거', '노브랜드', '신세계', '치즈볼', '절미', '치즈볼', '절미', '할미', '입맛', '입맛', '치즈', '스타', '그램', '신상', '리뷰', '호기심', '별', '점', '호기심', '노브랜드버거', '맛스타그램', '먹스타그램', '호기심']

# %%
words = []
for a in range(len(df)):
    words.append([])

# %%
len(words)
# Out:
# 40644

# %%
#토큰화 및 텍스트 데이터 전처리 

for a in range(len(df)):
    for word in token[a]:  #불용어 제거 

        if len(word)>1: 
            if word not in (list(stopwords['stopword'])):
                words[a].append(word)

# %%
print(words[0])
print(len(words))
# Out:
# ['ver', '오백', '예순', '호기심', '노브랜드버거', '인절미', '치즈볼', '요청', '눈길', '알바', '열띤', '영업', '노브랜드버거', '버거', '맛없', '평소', '사이드', '라서', '방문', '인절미', '치즈볼', '이름', '주루', '딴딴하게', '치즈볼', '어물', '어보', '미쳤구만', '맛있습니다', '취향', '고물', '설탕', '꼬소롬', '달콤달콤', '모짜렐라', '치즈', '짭쫍짭쫍', '고소', '치즈볼', '꼬북칩', '인절미', '해주', '알바', '진자', '여태', '치즈볼', '최고', '취향', '신상', '었습니닷', '노브랜드버거', '노브랜드', '신세계', '치즈볼', '절미', '치즈볼', '절미', '할미', '입맛', '입맛', '치즈', '스타', '신상', '호기심', '호기심', '노브랜드버거', '맛스타그램', '먹스타그램', '호기심']
# 40644

# %%
df['cleaned_content'] = words

# %%
df
# Out:
#              date  \
# 0      2020-09-24
# 1      2020-10-12
# 2      2020-10-10
# 3      2020-10-15
# 4      2020-10-17
# ...           ...
# 40639  2020-01-28
# 40640  2020-09-18
# 40641  2020-09-25
# 40642  2020-06-05
# 40643  2020-09-15
#
#                                                                                         title  \
# 0      오백예순두 번째 호기심까까  노브랜드버거 인절미치즈볼3알2900원   리뷰요청지에서...
# 1      광고공구예고  안녕하세요 뚜뚜네간식 뚜맘입니다  오래 기다려주신 오크리스피 최저가공...
# 2      _ 땡스피자 _ 오랜만에 먹은 땡스피자 못본 사이에 언제 이런 네가지 맛으로 즐길수...
# 3      광희나는메이플버터갈릭치킨 비비큐치즈볼 bbq bbqchicken 네고왕 으로 핫한 ...
# 4      배떡  방이점  로제떡볶이12인분 9000원 ...
# ...                                                               ...
# 40639  연휴가 끝나서 힘들고 지칠 때 멕시카나치킨 을 찾아주세요 매콤단짠  뿌리고치킨 에 ...
# 40640                    배달의민족 순수치킨 3000원 할인
# 40641          금요일은 배달의민족 순수치킨  3000원 할인
# 40642  또래오래 목우촌 배달의민족 쿠폰 프로모션 치킨 이번 주 금토일 치킨파티 각 쉿 6월...
# 40643  순수치킨이 새로 쓰는 치킨의정석  가성비가성비갓성비순수치킨......
#
#                                                                     cleaned_content
# 0      [ver, 오백, 예순, 호기심, 노브랜드버거, 인절미, 치즈볼, 요청, 눈길, 알...
# 1      [광고, 공구, 예고, 안녕, 뚜뚜, 간식, 뚜맘, 오래, 주신, 크리스, 최저, ...
# 2      [st, 땡스, 피자, 오랜만, 땡스, 피자, 사이, 네가지, 있게, 된거, 여러가...
# 3      [bbq, bbqchicken, BBQ, 광희, 메이플, 버터, 갈릭, 치킨, 비비...
# 4      [food, foodstagram, 서울, 송파구, 오금로, 배떡, 가까운, 방이역...
# ...                                                                  ...
# 40639  [연휴, 힘들고, 멕시, 카나, 치킨, 아주, 매콤, 뿌리, 고치, 쫀득, 더블, ...
# 40640                     [배달의민족, 순수, 치킨, 할인]
# 40641             [금요일, 배달의민족, 순수, 치킨, 할인]
# 40642  [또래오래, 우촌, 배달의민족, 쿠폰, 프로모션, 치킨, 금토일, 치킨, 파티, 일...
# 40643  [순수, 치킨, 새로, 치킨, 의정, 성비, 가성, 비갓, 성비, 순수, 치킨].....
#
# [40644 rows x 3 columns]

# %%
df['cleaned_content'][0]
# Out:
# ['ver',
#  '오백',
#  '예순',
#  '호기심',
#  '노브랜드버거',
#  '인절미',
#  '치즈볼',
#  '요청',
#  '눈길',
#  '알바',
#  '열띤',
#  '영업',
#  '노브랜드버거',
#  '버거',
#  '맛없',
#  '평소',
#  '사이드',
#  '라서',
#  '방문',
#  '인절미',
#  '치즈볼',
#  '이름',
#  '주루',
#  '딴딴하게',
#  '치즈볼',
#  '어물',
#  '어보',
#  '미쳤구만',
#  '맛있습니다',
#  '취향',
#  '고물',
#  '설탕',
#  '꼬소롬',
#  '달콤달콤',
#  '모짜렐라',
#  '치즈',
#  '짭쫍짭쫍',
#  '고소',
#  '치즈볼',
#  '꼬북칩',
#  '인절미',
#  '해주',
#  '알바',
#  '진자',
#  '여태',
#  '치즈볼',
#  '최고',
#  '취향',
#  '신상',
#  '었습니닷',
#  '노브랜드버거',
#  '노브랜드',
#  '신세계',
#  '치즈볼',
#  '절미',
#  '치즈볼',
#  '절미',
#  '할미',
#  '입맛',
#  '입맛',
#  '치즈',
#  '스타',
#  '신상',
#  '호기심',
#  '호기심',
#  '노브랜드버거',
#  '맛스타그램',
#  '먹스타그램',
#  '호기심']

# %%
for a in range(len(df)):
    df['cleaned_content'][a] = ' '.join(df['cleaned_content'][a])

# %%
print(df['cleaned_content'][:3])
# Out:
# 0    ver 오백 예순 호기심 노브랜드버거 인절미 치즈볼 요청 눈길 알바 열띤 영업 노브...
# 1    광고 공구 예고 안녕 뚜뚜 간식 뚜맘 오래 주신 크리스 최저 가공 드뎌 아아 신제품...
# 2    st 땡스 피자 오랜만 땡스 피자 사이 네가지 있게 된거 여러가지 야하는 딱이었고 ...
# Name: cleaned_content, dtype: object

# %%
df.to_csv('./crawling_data/clean_sentence_eng_noun_adj.csv')

# %%
#브랜드별 검색어 리스트 불러오기
brand = pd.read_csv('./brand.csv', index_col=0)
print(brand)
# Out:
#        brandname                                      brand
# 0            BHC        bhc 비에치씨 bhc치킨 비에이치씨치킨
# 1            BBQ              bbq 비비큐 bbq치킨 비비큐치킨
# 2       네네치킨                  네네치킨 네네 네네볼 nene
# 3       맘스터치         맘스터치 맘터 mom'stouch momstouch
# 4         푸라닭                      푸라닭 puradak 푸라닥
# 5       또래오래  또래오래 또래오래치킨 농협 목우촌 toreore
# 6     신전떡볶이            신전떡볶이 신전 신전치즈볼 신떡
# 7         처갓집           처갓집 처갓집양념치킨 처갓집치킨
# 8         풀무원                                     풀무원
# 9         애슐리                                     애슐리
# 10        버거킹                     버거킹 burgerking 벅킹
# 11            CJ                             cj 씨제이 고메
# 12      쿠캣마켓         쿠캣마켓 쿠캣 쿠켓 쿠켓마켓 cookat
# 13      코스트코                            코스트코 costco
# 14      마켓컬리            마켓컬리 컬리 marketkurly kurly
# 15        이마트            이마트 emart 트레이더스 traders
# 16      롯데리아                 롯데리아 롯리 치즈인더에그
# 17  노브랜드버거              노브랜드버거 노브랜드 nobrend

# %%
#프랜차이즈 리스트의 치킨 프랜차이즈들이 언급된 문장 갯수 구하기(브랜드 정보 추가)
brandcount=[]
for i in range(len(brand)):
    store_cleaned_content = []
    dates=[]
    for sentence in df['cleaned_content']:        
        token = sentence.split(' ')
        tokens = pd.DataFrame(token, columns=['token'])
        for word in (list(tokens['token'])):
            if word in brand['brand'][i].split(' '):
                store_cleaned_content.append(sentence)
                dates.append(df['date'][df[df['cleaned_content']== sentence].index[0]])   
    new_df = pd.DataFrame({'date':dates, brand['brandname'][i] : store_cleaned_content})
    new_df.to_csv('./brand/brand_{}.csv'.format(i))
    b_count = new_df[brand['brandname'][i]].count()
    print(brand['brandname'][i], ':', b_count)
    brandcount.append(b_count)
# Out:
# BHC : 5280
# BBQ : 3396
# 네네치킨 : 456
# 맘스터치 : 1354
# 푸라닭 : 1710
# 또래오래 : 749
# 신전떡볶이 : 423
# 처갓집 : 305
# 풀무원 : 998
# 애슐리 : 560
# 버거킹 : 178
# CJ : 42
# 쿠캣마켓 : 325
# 코스트코 : 158
# 마켓컬리 : 53
# 이마트 : 377
# 롯데리아 : 419
# 노브랜드버거 : 275

# %%
#브랜드와 언급횟수를 데이터 프레임으로 만들기
brands = {"brandname":brand['brandname'], "count":brandcount}
df_brand = pd.DataFrame(brands)
df_brand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   brandname  18 non-null     object
#  1   count      18 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
#언급횟수가 많은 순으로 정렬
df_brand.sort_values(by=['count'], axis=0, ascending=False, inplace=True)
df_brand.reset_index(drop=True, inplace=True)
df_brand
# Out:
#        brandname  count
# 0            BHC   5280
# 1            BBQ   3396
# 2         푸라닭   1710
# 3       맘스터치   1354
# 4         풀무원    998
# 5       또래오래    749
# 6         애슐리    560
# 7       네네치킨    456
# 8     신전떡볶이    423
# 9       롯데리아    419
# 10        이마트    377
# 11      쿠캣마켓    325
# 12        처갓집    305
# 13  노브랜드버거    275
# 14        버거킹    178
# 15      코스트코    158
# 16      마켓컬리     53
# 17            CJ     42

# %%
#브랜드별 언급빈도수 차트그리기
plt.bar(range(len(df_brand['count'])), df_brand['count'])
ax = plt.subplot()
ax.set_xticks(range(len(df_brand['brandname'])))
ax.set_xticklabels(df_brand['brandname'], rotation=30)
plt.title('Brand Trend', size=30)
plt.ylabel('Count', size=20)
plt.xlabel('Brand', size=20)
plt.show()
# Out:
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_df = pd.read_csv('./crawling_data/brand_0.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-337-ffc059923d6f> in <module>
# ----> 1 new_df = pd.read_csv('./crawling_data/brand_0.csv', index_col=0)
#
# 36   치즈볼
# 37   치즈볼
# 38   치즈볼
# 39   치즈볼
# 40   치즈볼
# 41   치즈볼
# 42   치즈볼
# 43   치즈볼
# 44   치즈볼
# 45   치즈볼
# 46   치즈볼
# 47   치즈볼
# 48   치즈볼
# 49   치즈볼
# 50   치즈볼
# 51   치즈볼
# 52   치즈볼
# 53   치즈볼
# 54   치즈볼
# 55   치즈볼
# 56   치즈볼
# 57   치즈볼
# 58   치즈볼
# 59   치즈볼
# 60   치즈볼
# 61   치즈볼
# 62   치즈볼
# 63   치즈볼
# 64   치즈볼
# 65   치즈볼
# 66   치즈볼
# 67   치즈볼
# 68   치즈볼
# 69   치즈볼
# 70   치즈볼
# 71   치즈볼
# 72   치즈볼
# 73   치즈볼
# 74   치즈볼
# 75   치즈볼
# 76   치즈볼
# 77   치즈볼
# 78   치즈볼
# 79   치즈볼
# 80   치즈볼
# 81   치즈볼
# 82   치즈볼
# 83   치즈볼
# 84   치즈볼
# 85   치즈볼
# 86   치즈볼
# 87   치즈볼
# 88   치즈볼
# 89   치즈볼
# 90   치즈볼
# 91   치즈볼
# 92   치즈볼
# 93   치즈볼
# 94   치즈볼
# 95   치즈볼
# 96   치즈볼
# 97   치즈볼
# 98   치즈볼
# 99   치즈볼
# 100  치즈볼
# 101  치즈볼
# 102  치즈볼
# 103  치즈볼
# 104  치즈볼
# 105  치즈볼
# 106  치즈볼
# 107  치즈볼
# 108  치즈볼
# 109  치즈볼
# 110  치즈볼
# 111  치즈볼
# 112  치즈볼
# 113  치즈볼
# 114  치즈볼
# 115  치즈볼
# 116  치즈볼
# 117  치즈볼
# 118  치즈볼
# 119  치즈볼
# 120  치즈볼
# 121  치즈볼
# 122  치즈볼
# 123  치즈볼
# 124  치즈볼
# 125  치즈볼
# 126  치즈볼
# 127  치즈볼
# 128  치즈볼
# 129  치즈볼
# 130  치즈볼
# 131  치즈볼
# 132  치즈볼
# 133  치즈볼
# 134  치즈볼
# 135  치즈볼
# 136  치즈볼
# 137  치즈볼
# 138  치즈볼
# 139  치즈볼
# 140  치즈볼
# 141  치즈볼
# 142  치즈볼
# 143  치즈볼
# 144  치즈볼
# 145  치즈볼
# 146  치즈볼
# 147  치즈볼
# 148  치즈볼
# 149  치즈볼
# 150  치즈볼
# 151  치즈볼
# 152  치즈볼
# 153  치즈볼
# 154  치즈볼
# 155  치즈볼
# 156  치즈볼
# 157  치즈볼
# 158  치즈볼
# 159  치즈볼
# 160  치즈볼
# 161  치즈볼
# 162  치즈볼
# 163  치즈볼
# 164  치즈볼
# 165  치즈볼
# 166  치즈볼
# 167  치즈볼
# 168  치즈볼
# 169  치즈볼
# 170  치즈볼
# 171  치즈볼
# 172  치즈볼
# 173  치즈볼
# 174  치즈볼
# 175  치즈볼
# 176  치즈볼
# 177  치즈볼
# 178  치즈볼
# 179  치즈볼
# 180  치즈볼
# 181  치즈볼
# 182  치즈볼
# 183  치즈볼
# 184  치즈볼
# 185  치즈볼
# 186  치즈볼
# 187  치즈볼
# 188  치즈볼
# 189  치즈볼
# 190  치즈볼
# 191  치즈볼
# 192  치즈볼
# 193  치즈볼
# 194  치즈볼
# 195  치즈볼
# 196  치즈볼
# 197  치즈볼
# 198  치즈볼
# 199  치즈볼
# 200  치즈볼
# 201  치즈볼
# 202  치즈볼
# 203  치즈볼
# 204  치즈볼
# 205  치즈볼
# 206  치즈볼
# 207  치즈볼
# 208  치즈볼
# 209  치즈볼
# 210  치즈볼
# 211  치즈볼
# 212  치즈볼
# 213  치즈볼
# 214  치즈볼
# 215  치즈볼
# 216  치즈볼
# 217  치즈볼
# 218  치즈볼
# 219  치즈볼
# 220  치즈볼
# 221  치즈볼
# 222  치즈볼
# 223  치즈볼
# 224  치즈볼
# 225  치즈볼
# 226  치즈볼
# 227  치즈볼
# 228  치즈볼
# 229  치즈볼
# 230  치즈볼
# 231  치즈볼
# 232  치즈볼
# 233  치즈볼
# 234  치즈볼
# 235  치즈볼
# 236  치즈볼
# 237  치즈볼
# 238  치즈볼
# 239  치즈볼
# 240  치즈볼
# 241  치즈볼
# 242  치즈볼
# 243  치즈볼
# 244  치즈볼
# 245  치즈볼
# 246  치즈볼
# 247  치즈볼
# 248  치즈볼
# 249  치즈볼
# 250  치즈볼
# 251  치즈볼
# 252  치즈볼
# 253  치즈볼
# 254  치즈볼
# 255  치즈볼
# 256  치즈볼
# 257  치즈볼
# 258  치즈볼
# 259  치즈볼
# 260  치즈볼
# 261  치즈볼
# 262  치즈볼
# 263  치즈볼
# 264  치즈볼
# 265  치즈볼
# 266  치즈볼
# 267  치즈볼
# 268  치즈볼
# 269  치즈볼
# 270  치즈볼
# 271  치즈볼
# 272  치즈볼
# 273  치즈볼
# 274  치즈볼

# %%
#이름이 바뀌는 컬럼명 위치 정보로 찾기
#new_df.columns[1]

# %%
#one sentence 만들기
review_one_sentences = []
titles = []

for title in new_df['title'].unique():
    temp = new_df[new_df['title']==title][new_df.columns[1]]
    review_one_sentence = ' '.join(list(temp)) 
    review_one_sentences.append(review_one_sentence)
    titles.append(title)
    
df_review_one_sentence = pd.DataFrame({'title':titles, 'review_one_sentence':review_one_sentences})
print(df_review_one_sentence.head())
print(df_review_one_sentence.info())
# Out:
#     title  \
# 0  치즈볼
#
#                                                                 review_one_sentence
# 0  ver 오백 예순 호기심 노브랜드버거 인절미 치즈볼 요청 눈길 알바 열띤 영업 노브...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                1 non-null      object
#  1   review_one_sentence  1 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes
# None

# %%
#one sentence로 합쳐진 데이터를 X에 저장 
X=df_review_one_sentence
print(X.head())
# Out:
#     title  \
# 0  치즈볼
#
#                                                                 review_one_sentence
# 0  ver 오백 예순 호기심 노브랜드버거 인절미 치즈볼 요청 눈길 알바 열띤 영업 노브...

# %%
#바꾸지 X 
_title='치즈볼'

# %%
_idx = X[X['title']==_title].index[0]

# %%
tokened_content_words = X['review_one_sentence'][_idx].split(' ')

# %%
textdict = collections.Counter(tokened_content_words)

# %%
wordcloude_img = WordCloud(background_color = 'white', max_words=150, font_path=font_path).generate_from_frequencies(textdict)
plt.figure(figsize=(16,16))
plt.imshow(wordcloude_img, interpolation='bilinear')
plt.axis('off')
plt.show()

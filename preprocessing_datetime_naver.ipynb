# %%
import time
import pandas as pd
import datetime
import numpy as np

# %%
#맨위의 read_csv와 맨아래의 to_csv 에서 파일명만 주의해주세요.

df = pd.read_csv('./prj_sns_trend_crawling_naver_cafe_치즈볼.csv')
df.drop([df.columns[0]],axis=1, inplace=True)
df
# Out:
#              date                                              title
# 0    2020.09.30.    단짠 치즈볼은 아니고 첫째 아이가 아기였을 때부터 하던 간단건강 치즈볼이에요 슬라...
# 1    2020.10.06.    거품은 제가 좋아해서 저렇게  코젤다크에 시나몬에그타르트곰곰치즈볼풀무원 앙크림치즈...
# 2    2020.10.04.    저는 제법 맛있었고 아내는 별로였고 치즈볼이 최고라고 하네요 치즈볼만 시켜먹고 싶...
# 3           7일 전    붕어빵도 먹고 치즈볼도 먹겠다해서 치즈볼 기름에 굴려주고 에어프라이에 한번더 그랬...
# 4    2020.09.28.    요즘 치즈볼에 흠뻑 빠졌어요 치킨 시킬때도 치즈볼 왕창 시켰는데 너무 비싸서 마트...
# ..            ...                                                ...
# 995  2020.09.18.    아이가 출출하다고 해서 치즈볼 했어요 역시 에프는 사랑입니다 그냥 돌리기만 하면 ...
# 996  2020.09.27.    그래서 치즈볼이랑 같이 먹으면 맛있다 히히 마지막 총평 오태식해바라기치킨  맛있긴...
# 997  2020.09.27.    출석111일차입니다 오늘 간식으로 치즈볼이 선택되었어요 크기도 크고 명랑핫도그 맛...
# 998  2020.09.21.    역시나 냄새만 맡고 안 먹고 어떻게해야 먹을까 고민고민 하다 사료를 믹서기로 갈아...
# 999  2020.10.02.    예를들면 치킨이라든지 양념치킨이라든지 간장치킨이라든지 매운치킨이라든지 치즈볼도 먹...
#
# [1000 rows x 2 columns]

# %%
#today = time.localtime(time.time())

for z in range(len(df['date'])):
    if '전' in df['date'][z]:


        if '일' in df['date'][z]:
            d = int(df['date'][z][0])
          
            new_date = datetime.datetime.now() - datetime.timedelta(days = d)            
            df['date'][z] = new_date


            
        else:
            new_date2 = datetime.datetime.now()
            df['date'][z] = new_date2
            
        
    elif '어제' in df['date'][z]:
        new_date3 = datetime.datetime.now() - datetime.timedelta(days = 1)
        df['date'][z] = new_date3

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
for z in range(len(df)): 
    df['date'][z] = df['date'][z].strftime('%Y-%m-%d')
# Out:
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#            date                                              title
# 0    2020-09-30   단짠 치즈볼은 아니고 첫째 아이가 아기였을 때부터 하던 간단건강 치즈볼이에요 슬라...
# 1    2020-10-06   거품은 제가 좋아해서 저렇게  코젤다크에 시나몬에그타르트곰곰치즈볼풀무원 앙크림치즈...
# 2    2020-10-04   저는 제법 맛있었고 아내는 별로였고 치즈볼이 최고라고 하네요 치즈볼만 시켜먹고 싶...
# 3    2020-10-07   붕어빵도 먹고 치즈볼도 먹겠다해서 치즈볼 기름에 굴려주고 에어프라이에 한번더 그랬...
# 4    2020-09-28   요즘 치즈볼에 흠뻑 빠졌어요 치킨 시킬때도 치즈볼 왕창 시켰는데 너무 비싸서 마트...
# ..          ...                                                ...
# 995  2020-09-18   아이가 출출하다고 해서 치즈볼 했어요 역시 에프는 사랑입니다 그냥 돌리기만 하면 ...
# 996  2020-09-27   그래서 치즈볼이랑 같이 먹으면 맛있다 히히 마지막 총평 오태식해바라기치킨  맛있긴...
# 997  2020-09-27   출석111일차입니다 오늘 간식으로 치즈볼이 선택되었어요 크기도 크고 명랑핫도그 맛...
# 998  2020-09-21   역시나 냄새만 맡고 안 먹고 어떻게해야 먹을까 고민고민 하다 사료를 믹서기로 갈아...
# 999  2020-10-02   예를들면 치킨이라든지 양념치킨이라든지 간장치킨이라든지 매운치킨이라든지 치즈볼도 먹...
#
# [1000 rows x 2 columns]

# %%
df.to_csv('prj_sns_trend_crawling_naver_cafe_치즈볼.csv')

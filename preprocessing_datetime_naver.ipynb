# %%
import time
import pandas as pd
import datetime
import numpy as np

# %%
#맨위의 read_csv와 맨아래의 to_csv 에서 파일명만 주의해주세요.

df = pd.read_csv('../prj_sns_trend_private/crawling_naver_cafe_치즈볼.csv')
df.drop([df.columns[0]],axis=1, inplace=True)
df
# Out:
#               date                                              title
# 0     2020.01.04.    지난 달 아들 둘과 저녁 외식 후 달달한 도넛을 간식으로 일심 동체 하여 구매 하...
# 1     2020.01.14.    치킨보다 치즈볼이 더 맛있네요 적당히 달고 맛있어서 순삭이네요 이럴 줄 알았으면 ...
# 2     2020.01.05.    시중에 파는 냉동 치즈볼이나 치킨집 치즈볼은 양도 적고 너무 비싸서 만들어 보기로...
# 3     2020.01.03.    아들이 치즈볼을 너무 좋아해서 치즈볼 만들어봤어요 생각보다 괜찮은거 같아요 치즈를...
# 4     2020.01.14.    페리카나에서 치킨 시켰는데 치즈볼 서비스로 주셨는데 넘 맛있네요 아기도 잘먹고 치...
# ...            ...                                                ...
# 9995  2020.10.09.   no253 꾸버스피자 포장 또는 배달주문시 치즈볼이벤트 진행합니다 금토일 포장 또는...
# 9996  2020.10.11.    친구가 사주는 치킨입니다 첫째랑 먹으라고 센스있게 순살 치즈볼까지 있어 푸짐합니다...
# 9997  2020.10.10.                                    치즈볼은 순싹 소세지도 순싹
# 9998  2020.10.12.    사람들이 가장 많이 구매하는 치즈볼 에어프라이어 가격할인 특가순위 지금 바로 보실...
# 9999  2020.10.09.   외식업계도 부캐 열풍사이드 메뉴 인기몰이 bhc치킨은 대표 사이드 메뉴는 2018년...
#
# [10000 rows x 2 columns]

# %%
for z in range(len(df['date'])):
    if '전' in df['date'][z]:


        if '일' in df['date'][z]:
            d = int(df['date'][z][0])
          
            new_date = datetime.datetime.now() - datetime.timedelta(days = d)            
            df['date'][z] = new_date


            
        else:
            new_date2 = datetime.datetime.now()
            df['date'][z] = new_date2
            
        
    elif '어제' in df['date'][z]:
        new_date3 = datetime.datetime.now() - datetime.timedelta(days = 1)
        df['date'][z] = new_date3

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
for z in range(len(df)):

    df['date'][z] = df['date'][z].strftime('%Y-%m-%d')
# Out:
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#             date                                              title
# 0     2020-01-04   지난 달 아들 둘과 저녁 외식 후 달달한 도넛을 간식으로 일심 동체 하여 구매 하...
# 1     2020-01-14   치킨보다 치즈볼이 더 맛있네요 적당히 달고 맛있어서 순삭이네요 이럴 줄 알았으면 ...
# 2     2020-01-05   시중에 파는 냉동 치즈볼이나 치킨집 치즈볼은 양도 적고 너무 비싸서 만들어 보기로...
# 3     2020-01-03   아들이 치즈볼을 너무 좋아해서 치즈볼 만들어봤어요 생각보다 괜찮은거 같아요 치즈를...
# 4     2020-01-14   페리카나에서 치킨 시켰는데 치즈볼 서비스로 주셨는데 넘 맛있네요 아기도 잘먹고 치...
# ...          ...                                                ...
# 9995  2020-10-09  no253 꾸버스피자 포장 또는 배달주문시 치즈볼이벤트 진행합니다 금토일 포장 또는...
# 9996  2020-10-11   친구가 사주는 치킨입니다 첫째랑 먹으라고 센스있게 순살 치즈볼까지 있어 푸짐합니다...
# 9997  2020-10-10                                   치즈볼은 순싹 소세지도 순싹
# 9998  2020-10-12   사람들이 가장 많이 구매하는 치즈볼 에어프라이어 가격할인 특가순위 지금 바로 보실...
# 9999  2020-10-09  외식업계도 부캐 열풍사이드 메뉴 인기몰이 bhc치킨은 대표 사이드 메뉴는 2018년...
#
# [10000 rows x 2 columns]

# %%
df.to_csv('./crawling_data/crawling_naver_cafe_치즈볼.csv')

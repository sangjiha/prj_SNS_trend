# %%
import pandas as pd

# %%
df1 = pd.read_csv('./crawling_data/crawling_naver_blog_치즈볼.csv')
df2 = pd.read_csv('./crawling_data/crawling_naver_cafe_치즈볼.csv')
df1 = pd.concat([df1,df2], ignore_index=True)
df1
# Out:
#        Unnamed: 0        date  \
# 0               0  2020-01-18
# 1               1  2020-02-01
# 2               2  2020-01-14
# 3               3  2020-01-02
# 4               4  2020-01-16
# ...           ...         ...
# 19995        9995  2020-10-09
# 19996        9996  2020-10-11
# 19997        9997  2020-10-10
# 19998        9998  2020-10-12
# 19999        9999  2020-10-09
#
#                                                    title
# 0      피자헛 신메뉴 이탈리안 살시챠고르곤졸라 치즈볼까지 알차게 고르곤졸라 치즈볼도 PIC...
# 1      서툰요리 찹쌀호떡믹스로 치즈볼 만들기 도전 나만의 레시피 안녀어어어엉 치즈볼만들기 ...
# 2      bhc 뿌링클과 치즈볼은 진리인 것이니라 늘어나는 치즈와 만나니 얼마나 맛있겠습니까...
# 3      교촌 치즈볼  닭갈비볶음밥 먹어본 솔직한 후기 저희는 고르곤으로 했어요 흑 요새 왜...
# 4      7번가피자 치즈볼 솔직후기 and 샘스테이크피자 요기꺼 먹고 진심  욕했어욬 뭐얔 ...
# ...                                                  ...
# 19995  no253 꾸버스피자 포장 또는 배달주문시 치즈볼이벤트 진행합니다 금토일 포장 또는...
# 19996   친구가 사주는 치킨입니다 첫째랑 먹으라고 센스있게 순살 치즈볼까지 있어 푸짐합니다...
# 19997                                   치즈볼은 순싹 소세지도 순싹
# ...

# %%
df1.drop_duplicates(inplace=True)
df1.drop([df1.columns[0]],axis=1, inplace=True)
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#              date                                              title
# 0      2020-01-18  피자헛 신메뉴 이탈리안 살시챠고르곤졸라 치즈볼까지 알차게 고르곤졸라 치즈볼도 PIC...
# 1      2020-02-01  서툰요리 찹쌀호떡믹스로 치즈볼 만들기 도전 나만의 레시피 안녀어어어엉 치즈볼만들기 ...
# 2      2020-01-14  bhc 뿌링클과 치즈볼은 진리인 것이니라 늘어나는 치즈와 만나니 얼마나 맛있겠습니까...
# 3      2020-01-02  교촌 치즈볼  닭갈비볶음밥 먹어본 솔직한 후기 저희는 고르곤으로 했어요 흑 요새 왜...
# 4      2020-01-16  7번가피자 치즈볼 솔직후기 and 샘스테이크피자 요기꺼 먹고 진심  욕했어욬 뭐얔 ...
# ...           ...                                                ...
# 19995  2020-10-09  no253 꾸버스피자 포장 또는 배달주문시 치즈볼이벤트 진행합니다 금토일 포장 또는...
# 19996  2020-10-11   친구가 사주는 치킨입니다 첫째랑 먹으라고 센스있게 순살 치즈볼까지 있어 푸짐합니다...
# 19997  2020-10-10                                   치즈볼은 순싹 소세지도 순싹
# 19998  2020-10-12   사람들이 가장 많이 구매하는 치즈볼 에어프라이어 가격할인 특가순위 지금 바로 보실...
# 19999  2020-10-09  외식업계도 부캐 열풍사이드 메뉴 인기몰이 bhc치킨은 대표 사이드 메뉴는 2018년...
#
# [20000 rows x 2 columns]

# %%
df1.to_csv('./crawling_data/only_naver.csv')

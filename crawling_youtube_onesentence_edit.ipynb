# %%
import pandas as pd

# %%
df = pd.read_csv('./crawling_data/crawling_youtube_final.csv')
df.drop([df.columns[0]], axis=1, inplace=True)
df
# Out:
#                                 youtuber        date  \
# 0                               애주가TV참PD  2020-04-02
# 1                            핏블리 FITVELY  2020-09-14
# 2                                   BODA  2020-09-18
# 3    [헬스창고] 헬창TV / Korean Fitness Garage  2020-09-16
# 4                             쯔양 영상 다시보기  2020-09-20
# ..                                   ...         ...
# 103                        다먹 ASMR Damuk  2020-03-02
# 104                                  떵개떵  2020-04-04
# 105                          하니얌 haniyam  2020-03-29
# 106                                 교광TV  2020-02-10
# 107                                 상남자1  2020-04-09
#
#                                                  title  \
# 0                                 BHC 치즈볼 긴장해야 할거같습니다.
# 1          코로나19로 헬스장 문닫고 타락한 헬창, 살면서 처음먹는 치즈볼..눈물의 먹방
# 2                        난생 처음 뿌링클, 치즈볼을 먹어보고 타락한 미국헬창
# 3        살면서 처음먹는 치즈볼.. [타락헬창] BJ 치즈볼과 함께한 타락여행.. VLOG
# ...

# %%
df.rename(columns = {'youtuber': 'id'}, inplace = True)
df.drop_duplicates(subset= 'title', inplace=True)
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                      id        date  \
# 0                              애주가TV참PD  2020-04-02
# 1                           핏블리 FITVELY  2020-09-14
# 2                                  BODA  2020-09-18
# 3   [헬스창고] 헬창TV / Korean Fitness Garage  2020-09-16
# 4                            쯔양 영상 다시보기  2020-09-20
# ..                                  ...         ...
# 85                        다먹 ASMR Damuk  2020-03-02
# 86                                  떵개떵  2020-04-04
# 87                          하니얌 haniyam  2020-03-29
# 88                                 교광TV  2020-02-10
# 89                                 상남자1  2020-04-09
#
#                                                 title  \
# 0                                BHC 치즈볼 긴장해야 할거같습니다.
# 1         코로나19로 헬스장 문닫고 타락한 헬창, 살면서 처음먹는 치즈볼..눈물의 먹방
# 2                       난생 처음 뿌링클, 치즈볼을 먹어보고 타락한 미국헬창
# 3       살면서 처음먹는 치즈볼.. [타락헬창] BJ 치즈볼과 함께한 타락여행.. VLOG
# 4   [Tzuyang쯔양] BHC 치즈볼 100개 도전 먹방 Korean mukbang ...
# ...

# %%
df['likes'] = df['likes'].astype('int')
df
# Out:
#                                      id        date  \
# 0                              애주가TV참PD  2020-04-02
# 1                           핏블리 FITVELY  2020-09-14
# 2                                  BODA  2020-09-18
# 3   [헬스창고] 헬창TV / Korean Fitness Garage  2020-09-16
# 4                            쯔양 영상 다시보기  2020-09-20
# ..                                  ...         ...
# 85                        다먹 ASMR Damuk  2020-03-02
# 86                                  떵개떵  2020-04-04
# 87                          하니얌 haniyam  2020-03-29
# 88                                 교광TV  2020-02-10
# 89                                 상남자1  2020-04-09
#
#                                                 title  \
# 0                                BHC 치즈볼 긴장해야 할거같습니다.
# 1         코로나19로 헬스장 문닫고 타락한 헬창, 살면서 처음먹는 치즈볼..눈물의 먹방
# 2                       난생 처음 뿌링클, 치즈볼을 먹어보고 타락한 미국헬창
# 3       살면서 처음먹는 치즈볼.. [타락헬창] BJ 치즈볼과 함께한 타락여행.. VLOG
# 4   [Tzuyang쯔양] BHC 치즈볼 100개 도전 먹방 Korean mukbang ...
# ...

# %%
df.to_csv('./crawling_data/crawling_youtube_final.csv')

# %%
for i in range(len(df)):
    df['title'][i] = ' ' +  df['id'][i] + ' ' + df['title'][i] + ' ' + df['comment'][i]
df
# Out:
# c:\users\07\anaconda3\envs\machinelearning\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      id        date  \
# 0                              애주가TV참PD  2020-04-02
# 1                           핏블리 FITVELY  2020-09-14
# 2                                  BODA  2020-09-18
# 3   [헬스창고] 헬창TV / Korean Fitness Garage  2020-09-16
# 4                            쯔양 영상 다시보기  2020-09-20
# ..                                  ...         ...
# 85                        다먹 ASMR Damuk  2020-03-02
# 86                                  떵개떵  2020-04-04
# 87                          하니얌 haniyam  2020-03-29
# 88                                 교광TV  2020-02-10
# 89                                 상남자1  2020-04-09
#
# ...

# %%
df.drop([df.columns[3]], axis=1, inplace=True)
df
# Out:
#                                      id        date  \
# 0                              애주가TV참PD  2020-04-02
# 1                           핏블리 FITVELY  2020-09-14
# 2                                  BODA  2020-09-18
# 3   [헬스창고] 헬창TV / Korean Fitness Garage  2020-09-16
# 4                            쯔양 영상 다시보기  2020-09-20
# ..                                  ...         ...
# 85                        다먹 ASMR Damuk  2020-03-02
# 86                                  떵개떵  2020-04-04
# 87                          하니얌 haniyam  2020-03-29
# 88                                 교광TV  2020-02-10
# 89                                 상남자1  2020-04-09
#
#                                                 title
# 0    애주가TV참PD BHC 치즈볼 긴장해야 할거같습니다.  전국의 치즈볼이 씨가 마르...
# 1    핏블리 FITVELY 코로나19로 헬스장 문닫고 타락한 헬창, 살면서 처음먹는 치...
# 2    BODA 난생 처음 뿌링클, 치즈볼을 먹어보고 타락한 미국헬창  외국인 맞냐 내가...
# 3    [헬스창고] 헬창TV / Korean Fitness Garage 살면서 처음먹는 ...
# 4    쯔양 영상 다시보기 [Tzuyang쯔양] BHC 치즈볼 100개 도전 먹방 Kor...
# ...

# %%
df.drop([df.columns[2]], axis=1, inplace=True)
df
# Out:
#           date                                              title
# 0   2020-04-02   애주가TV참PD BHC 치즈볼 긴장해야 할거같습니다.  전국의 치즈볼이 씨가 마르...
# 1   2020-09-14   핏블리 FITVELY 코로나19로 헬스장 문닫고 타락한 헬창, 살면서 처음먹는 치...
# 2   2020-09-18   BODA 난생 처음 뿌링클, 치즈볼을 먹어보고 타락한 미국헬창  외국인 맞냐 내가...
# 3   2020-09-16   [헬스창고] 헬창TV / Korean Fitness Garage 살면서 처음먹는 ...
# 4   2020-09-20   쯔양 영상 다시보기 [Tzuyang쯔양] BHC 치즈볼 100개 도전 먹방 Kor...
# ..         ...                                                ...
# 85  2020-03-02   다먹 ASMR Damuk ASMR 치즈볼 아니고 초코볼 🍫 초코 찹쌀도넛 먹방 C...
# 86  2020-04-04   떵개떵 오랜만에 먹는 뿌링클닭다리와 치즈볼, 꿀호떡, 소떡소떡 사이드메뉴 먹방~!...
# 87  2020-03-29   하니얌 haniyam 먹방브이로그 | 60계간지치킨+치즈볼, 짜파게티+파김치, 편...
# 88  2020-02-10   교광TV BHC뿌링클닭다리치킨 치즈볼 먹방ASMR MUKBANG Sweet Chi...
# 89  2020-04-09   상남자1 우유 1500번 저어서 치즈 만들기 + 치즈볼  4:44 급발진 개웃기네...
#
# [90 rows x 2 columns]

# %%
df.drop([df.columns[0]], axis=1, inplace=True)
df
# Out:
#           date                                              title
# 0   2020-04-02   애주가TV참PD BHC 치즈볼 긴장해야 할거같습니다.  전국의 치즈볼이 씨가 마르...
# 1   2020-09-14   핏블리 FITVELY 코로나19로 헬스장 문닫고 타락한 헬창, 살면서 처음먹는 치...
# 2   2020-09-18   BODA 난생 처음 뿌링클, 치즈볼을 먹어보고 타락한 미국헬창  외국인 맞냐 내가...
# 3   2020-09-16   [헬스창고] 헬창TV / Korean Fitness Garage 살면서 처음먹는 ...
# 4   2020-09-20   쯔양 영상 다시보기 [Tzuyang쯔양] BHC 치즈볼 100개 도전 먹방 Kor...
# ..         ...                                                ...
# 85  2020-03-02   다먹 ASMR Damuk ASMR 치즈볼 아니고 초코볼 🍫 초코 찹쌀도넛 먹방 C...
# 86  2020-04-04   떵개떵 오랜만에 먹는 뿌링클닭다리와 치즈볼, 꿀호떡, 소떡소떡 사이드메뉴 먹방~!...
# 87  2020-03-29   하니얌 haniyam 먹방브이로그 | 60계간지치킨+치즈볼, 짜파게티+파김치, 편...
# 88  2020-02-10   교광TV BHC뿌링클닭다리치킨 치즈볼 먹방ASMR MUKBANG Sweet Chi...
# 89  2020-04-09   상남자1 우유 1500번 저어서 치즈 만들기 + 치즈볼  4:44 급발진 개웃기네...
#
# [90 rows x 2 columns]

# %%
df.to_csv('./crawling_data/crawling_youtube_final_date_title.csv')
